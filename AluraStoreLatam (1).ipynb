# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
ingreso_total_tienda1 = tienda['Precio'].sum()
ingreso_total_tienda2 = tienda2['Precio'].sum()
ingreso_total_tienda3 = tienda3['Precio'].sum()
ingreso_total_tienda4 = tienda4['Precio'].sum()

print(f"Ingreso total Tienda 1: {ingreso_total_tienda1}")
print(f"Ingreso total Tienda 2: {ingreso_total_tienda2}")
print(f"Ingreso total Tienda 3: {ingreso_total_tienda3}")
print(f"Ingreso total Tienda 4: {ingreso_total_tienda4}")

# %% [markdown]
# # 2. Ventas por categoría

# %%
ventas_por_categoria_tienda1 = tienda['Categoría del Producto'].value_counts()
ventas_por_categoria_tienda2 = tienda2['Categoría del Producto'].value_counts()
ventas_por_categoria_tienda3 = tienda3['Categoría del Producto'].value_counts()
ventas_por_categoria_tienda4 = tienda4['Categoría del Producto'].value_counts()

print("Ventas por Categoría - Tienda 1:")
print(ventas_por_categoria_tienda1)
print("\nVentas por Categoría - Tienda 2:")
print(ventas_por_categoria_tienda2)
print("\nVentas por Categoría - Tienda 3:")
print(ventas_por_categoria_tienda3)
print("\nVentas por Categoría - Tienda 4:")
print(ventas_por_categoria_tienda4)

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
calificacion_promedio_tienda1 = tienda['Calificación'].mean()
calificacion_promedio_tienda2 = tienda2['Calificación'].mean()
calificacion_promedio_tienda3 = tienda3['Calificación'].mean()
calificacion_promedio_tienda4 = tienda4['Calificación'].mean()

print(f"Calificación promedio Tienda 1: {calificacion_promedio_tienda1}")
print(f"Calificación promedio Tienda 2: {calificacion_promedio_tienda2}")
print(f"Calificación promedio Tienda 3: {calificacion_promedio_tienda3}")
print(f"Calificación promedio Tienda 4: {calificacion_promedio_tienda4}")

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
productos_vendidos_tienda1 = tienda['Producto'].value_counts()
productos_vendidos_tienda2 = tienda2['Producto'].value_counts()
productos_vendidos_tienda3 = tienda3['Producto'].value_counts()
productos_vendidos_tienda4 = tienda4['Producto'].value_counts()

print("Productos más y menos vendidos - Tienda 1:")
print("Más vendidos:")
print(productos_vendidos_tienda1.head())
print("\nMenos vendidos:")
print(productos_vendidos_tienda1.tail())

print("\nProductos más y menos vendidos - Tienda 2:")
print("Más vendidos:")
print(productos_vendidos_tienda2.head())
print("\nMenos vendidos:")
print(productos_vendidos_tienda2.tail())

print("\nProductos más y menos vendidos - Tienda 3:")
print("Más vendidos:")
print(productos_vendidos_tienda3.head())
print("\nMenos vendidos:")
print(productos_vendidos_tienda3.tail())

print("\nProductos más y menos vendidos - Tienda 4:")
print("Más vendidos:")
print(productos_vendidos_tienda4.head())
print("\nMenos vendidos:")
print(productos_vendidos_tienda4.tail())

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
envio_promedio_tienda1 = tienda['Costo de envío'].mean()
envio_promedio_tienda2 = tienda2['Costo de envío'].mean()
envio_promedio_tienda3 = tienda3['Costo de envío'].mean()
envio_promedio_tienda4 = tienda4['Costo de envío'].mean()

print(f"Costo de envío promedio Tienda 1: {envio_promedio_tienda1}")
print(f"Costo de envío promedio Tienda 2: {envio_promedio_tienda2}")
print(f"Costo de envío promedio Tienda 3: {envio_promedio_tienda3}")
print(f"Costo de envío promedio Tienda 4: {envio_promedio_tienda4}")

# %%
# %pip install -U pip matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 23.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 67.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.10.0
#     Uninstalling matplotlib-3.10.0:
#       Successfully uninstalled matplotlib-3.10.0
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load the dataframes
url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

# Recalculate revenue variables
ingreso_total_tienda1 = tienda['Precio'].sum()
ingreso_total_tienda2 = tienda2['Precio'].sum()
ingreso_total_tienda3 = tienda3['Precio'].sum()
ingreso_total_tienda4 = tienda4['Precio'].sum()


tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']
ingresos = [ingreso_total_tienda1, ingreso_total_tienda2, ingreso_total_tienda3, ingreso_total_tienda4]

plt.figure(figsize=(10, 6))
plt.bar(tiendas, ingresos, color=['blue', 'green', 'red', 'purple'])
plt.xlabel('Tienda')
plt.ylabel('Ingreso Total')
plt.title('Análisis de Facturación por Tienda')
plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(15, 10))

ventas_por_categoria_tienda1 = tienda['Categoría del Producto'].value_counts()
ventas_por_categoria_tienda2 = tienda2['Categoría del Producto'].value_counts()
ventas_por_categoria_tienda3 = tienda3['Categoría del Producto'].value_counts()
ventas_por_categoria_tienda4 = tienda4['Categoría del Producto'].value_counts()

axes[0, 0].pie(ventas_por_categoria_tienda1, labels=ventas_por_categoria_tienda1.index, autopct='%1.1f%%', startangle=90)
axes[0, 0].set_title('Ventas por Categoría - Tienda 1')

axes[0, 1].pie(ventas_por_categoria_tienda2, labels=ventas_por_categoria_tienda2.index, autopct='%1.1f%%', startangle=90)
axes[0, 1].set_title('Ventas por Categoría - Tienda 2')

axes[1, 0].pie(ventas_por_categoria_tienda3, labels=ventas_por_categoria_tienda3.index, autopct='%1.1f%%', startangle=90)
axes[1, 0].set_title('Ventas por Categoría - Tienda 3')

axes[1, 1].pie(ventas_por_categoria_tienda4, labels=ventas_por_categoria_tienda4.index, autopct='%1.1f%%', startangle=90)
axes[1, 1].set_title('Ventas por Categoría - Tienda 4')

fig.suptitle('Distribución de Ventas por Categoría en las Tiendas', fontsize=16)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(15, 10))
fig.suptitle('Productos más y menos vendidos por Tienda', fontsize=16)

stores = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']
axes = axes.flatten()

for i, store in enumerate(stores):
    store_data = all_products[all_products['Store'] == store].sort_values('Sales Count', ascending=False)
    axes[i].barh(store_data['Product'], store_data['Sales Count'], color=plt.cm.viridis(i/len(stores)))
    axes[i].set_title(f'Productos más y menos vendidos - {store}')
    axes[i].set_xlabel('Cantidad de Ventas')
    axes[i].invert_yaxis()

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
Analisis: la tienda que deberia vender don juan es la tienda numero 4, ya que es la menos ingresos obtuvo.
